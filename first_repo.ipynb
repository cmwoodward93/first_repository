# %% [markdown]
# ## this is my first notebook. i am using this to figure out what im doing
#
# i will put some simple code underneath

# %%
print("hello world. how original")
2+2
12-5
# Out:
# hello world. how original
# 7
